# %% [markdown]
# <a href="https://colab.research.google.com/github/FilipCichosz/BIAI-Project-sports-betting-In-progress/blob/master/prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
matchfe = "/content/drive/MyDrive/matches.csv"

# %%
matches = pd.read_csv(matchfe, index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2023-08-12  12:30  Premier League  Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00  Premier League  Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00  Premier League  Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30  Premier League  Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30  Premier League  Matchweek 5  Sun  Away      W  1.0  0.0
#
#           opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 1  Nott'ham Forest  ...  Match Report    NaN  15.0  7.0  19.1  0.0  0     0
# 2   Crystal Palace  ...  Match Report    NaN  13.0  2.0  16.4  0.0  1     1
# 3           Fulham  ...  Match Report    NaN  18.0  9.0  13.8  0.0  1     1
# 4   Manchester Utd  ...  Match Report    NaN  17.0  5.0  15.0  0.0  0     0
# 5          Everton  ...  Match Report    NaN  13.0  4.0  17.4  0.0  0     0
#
#    season     team
# 1    2024  Arsenal
# ...

# %%
matches.shape
# Out:
# (1386, 27)

# %%
# 2 seasons * 20 squads * 38 matches

2 * 20 * 38
# Out:
# 1520

# %%
# Missing Liverpool 2022-2024
matches["team"].value_counts()
# Out:
# team
# Nottingham Forest           70
# Aston Villa                 70
# Brentford                   70
# West Ham United             70
# Fulham                      70
# Arsenal                     69
# Wolverhampton Wanderers     69
# Everton                     69
# Crystal Palace              69
# Liverpool                   69
# Bournemouth                 69
# Brighton and Hove Albion    69
# Newcastle United            69
# Manchester United           69
# Tottenham Hotspur           69
# Manchester City             69
# Chelsea                     68
# Leicester City              38
# Leeds United                38
# Southampton                 38
# Luton Town                  32
# Burnley                     32
# Sheffield United            31
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2022-08-06  12:30  Premier League   Matchweek 1  Sat  Away      D  2.0
# 2   2022-08-15  20:00  Premier League   Matchweek 2  Mon  Home      D  1.0
# 3   2022-08-22  20:00  Premier League   Matchweek 3  Mon  Away      L  1.0
# 4   2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W  9.0
# 5   2022-08-31  20:00  Premier League   Matchweek 5  Wed  Home      W  2.0
# ..         ...    ...             ...           ...  ...   ...    ...  ...
# 41  2024-03-02  15:00  Premier League  Matchweek 27  Sat  Away      W  1.0
# 43  2024-03-10  15:45  Premier League  Matchweek 28  Sun  Home      D  1.0
# 46  2024-03-31  14:00  Premier League  Matchweek 30  Sun  Home      W  2.0
# 47  2024-04-04  19:30  Premier League  Matchweek 31  Thu  Home      W  3.0
# 48  2024-04-07  15:30  Premier League  Matchweek 32  Sun  Away      D  2.0
#
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     40
# Matchweek 17    40
# Matchweek 32    40
# Matchweek 31    40
# Matchweek 30    40
# Matchweek 28    40
# Matchweek 27    40
# Matchweek 25    40
# Matchweek 24    40
# Matchweek 23    40
# Matchweek 22    40
# Matchweek 21    40
# Matchweek 2     40
# Matchweek 19    40
# Matchweek 18    40
# Matchweek 20    40
# Matchweek 16    40
# Matchweek 8     40
# Matchweek 3     40
# Matchweek 4     40
# Matchweek 5     40
# Matchweek 15    40
# Matchweek 7     40
# Matchweek 6     40
# Matchweek 9     40
# Matchweek 10    40
# Matchweek 11    40
# Matchweek 12    40
# Matchweek 13    40
# Matchweek 14    40
# Matchweek 26    38
# Matchweek 29    28
# Matchweek 33    20
# Matchweek 34    20
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = matches["result"].apply(lambda x: 1 if x == 'W' else (0 if x == 'D' else -1))

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2023-08-12  12:30   Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00   Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00   Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30   Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30   Matchweek 5  Sun  Away      W  1.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2023-04-30  14:00  Matchweek 34  Sun  Away      L  1.0  3.0
# 43 2023-05-08  20:00  Matchweek 35  Mon  Away      L  3.0  4.0
# 44 2023-05-13  15:00  Matchweek 36  Sat  Home      L  0.0  2.0
# 45 2023-05-21  14:00  Matchweek 37  Sun  Away      L  1.0  3.0
# 46 2023-05-28  16:30  Matchweek 38  Sun  Home      D  4.0  4.0
#
#            opponent   xg  ...  match report    sh   sot  dist   fk pk pkatt  \
# 1   Nott'ham Forest  0.8  ...  Match Report  15.0   7.0  19.1  0.0  0     0
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2023-08-12  12:30   Matchweek 1  Sat  Home      W  2.0  1.0
# 2  2023-08-21  20:00   Matchweek 2  Mon  Away      W  1.0  0.0
# 3  2023-08-26  15:00   Matchweek 3  Sat  Home      D  2.0  2.0
# 4  2023-09-03  16:30   Matchweek 4  Sun  Home      W  3.0  1.0
# 5  2023-09-17  16:30   Matchweek 5  Sun  Away      W  1.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2023-04-30  14:00  Matchweek 34  Sun  Away      L  1.0  3.0
# 43 2023-05-08  20:00  Matchweek 35  Mon  Away      L  3.0  4.0
# 44 2023-05-13  15:00  Matchweek 36  Sat  Home      L  0.0  2.0
# 45 2023-05-21  14:00  Matchweek 37  Sun  Away      L  1.0  3.0
# 46 2023-05-28  16:30  Matchweek 38  Sun  Home      D  4.0  4.0
#
#            opponent   xg  ...   fk  pk  pkatt season         team target  \
# 1   Nott'ham Forest  0.8  ...  0.0   0      0   2024      Arsenal      1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2023-01-01']

# %%
test = matches[matches["date"] > '2023-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "gf", "ga", "xg", "xga", "poss", "sh", "sot"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.9193548387096774

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted   -1    0    1
# actual
# -1         394    6    7
#  0          21  181   38
#  1           7    6  394

# %%
from sklearn.metrics import precision_score, accuracy_score, classification_report

precision = precision_score(test["target"], preds, average='macro')

precision
# Out:
# 0.9229891428451991

# %%
report = classification_report(test["target"], preds)

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 4  2022-08-27  15:00   Matchweek 4  Sat  Home      W  4.0  2.0
# 5  2022-08-31  19:30   Matchweek 5  Wed  Home      W  6.0  0.0
# 6  2022-09-03  17:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2022-09-17  12:30   Matchweek 8  Sat  Away      W  3.0  0.0
# 10 2022-10-02  14:00   Matchweek 9  Sun  Home      W  6.0  3.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 39 2024-03-03  15:30  Matchweek 27  Sun  Home      W  3.0  1.0
# 41 2024-03-10  15:45  Matchweek 28  Sun  Away      D  1.0  1.0
# 43 2024-03-31  16:30  Matchweek 30  Sun  Home      D  0.0  0.0
# 44 2024-04-03  20:15  Matchweek 31  Wed  Home      W  4.0  1.0
# 45 2024-04-06  12:30  Matchweek 32  Sat  Away      W  4.0  2.0
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 4    Crystal Palace  2.2  ...    15         5    3.000000   1.000000
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W
#                         4  2022-08-31  19:30   Matchweek 5  Wed  Home      W
#                         5  2022-09-04  16:30   Matchweek 6  Sun  Away      L
#                         7  2022-09-18  12:00   Matchweek 8  Sun  Away      W
#                         8  2022-10-01  12:30   Matchweek 9  Sat  Home      W
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 32 2024-03-02  15:00  Matchweek 27  Sat  Away      L
#                         33 2024-03-09  15:00  Matchweek 28  Sat  Home      W
#                         35 2024-03-30  17:30  Matchweek 30  Sat  Away      L
#                         36 2024-04-02  19:45  Matchweek 31  Tue  Away      D
#                         37 2024-04-06  15:00  Matchweek 32  Sat  Home      L
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling
# Out:
#          date   time         round  day venue result   gf   ga  \
# 3  2022-08-27  17:30   Matchweek 4  Sat  Home      W  2.0  1.0
# 4  2022-08-31  19:30   Matchweek 5  Wed  Home      W  2.0  1.0
# 5  2022-09-04  16:30   Matchweek 6  Sun  Away      L  1.0  3.0
# 7  2022-09-18  12:00   Matchweek 8  Sun  Away      W  3.0  0.0
# 8  2022-10-01  12:30   Matchweek 9  Sat  Home      W  3.0  1.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 32 2024-03-02  15:00  Matchweek 27  Sat  Away      L  0.0  3.0
# 33 2024-03-09  15:00  Matchweek 28  Sat  Home      W  2.0  1.0
# 35 2024-03-30  17:30  Matchweek 30  Sat  Away      L  0.0  2.0
# 36 2024-04-02  19:45  Matchweek 31  Tue  Away      D  1.0  1.0
# 37 2024-04-06  15:00  Matchweek 32  Sat  Home      L  1.0  2.0
#
#           opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 3           Fulham  2.6  ...    17         5    3.000000   0.666667
# 4      Aston Villa  2.4  ...    19         2    3.000000   1.000000
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2023-01-01']
    test = data[data["date"] > '2023-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds, average='macro')
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.8746113146113146

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team         opponent result
# 13       0          0 2023-01-03  Arsenal    Newcastle Utd      D
# 14       1          1 2023-01-15  Arsenal        Tottenham      W
# 15       1          1 2023-01-22  Arsenal   Manchester Utd      W
# 16      -1         -1 2023-02-04  Arsenal          Everton      L
# 17       0          0 2023-02-11  Arsenal        Brentford      D
# 18      -1         -1 2023-02-15  Arsenal  Manchester City      L
# 19       1          1 2023-02-18  Arsenal      Aston Villa      W
# 20       1          1 2023-02-25  Arsenal   Leicester City      W
# 21       1          1 2023-03-01  Arsenal          Everton      W
# 22       1          1 2023-03-04  Arsenal      Bournemouth      W

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  predicted_x       date                   team_x  \
# 0           0            0 2023-01-03                  Arsenal
# 1           1            1 2023-01-15                  Arsenal
# 2           1            1 2023-01-22                  Arsenal
# 3          -1           -1 2023-02-04                  Arsenal
# 4           0            0 2023-02-11                  Arsenal
# ..        ...          ...        ...                      ...
# 951        -1           -1 2024-03-02  Wolverhampton Wanderers
# 952         1            1 2024-03-09  Wolverhampton Wanderers
# 953        -1           -1 2024-03-30  Wolverhampton Wanderers
# 954         0            0 2024-04-02  Wolverhampton Wanderers
# 955        -1           -1 2024-04-06  Wolverhampton Wanderers
#
#          opponent_x result_x new_team_x  actual_y  predicted_y  \
# 0     Newcastle Utd        D    Arsenal         0            0
# 1         Tottenham        W    Arsenal        -1           -1
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 0    9
# 1    1
# Name: count, dtype: int64
